# %% [markdown]
# <a href="https://colab.research.google.com/github/mvq23/python_23/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# %%
plt.plot(x, y, marker='o')  # 'o' agrega puntos en el gráfico

# %%
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Prueba')
# Out:
# Text(0.5, 1.0, 'Gráfico de Prueba')

# %%
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Prueba')
plt.show()
